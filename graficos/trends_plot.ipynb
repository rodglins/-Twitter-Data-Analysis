# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel (r'trends.xls')
print(df)
# Out:
#                        \tname  \ttweet_volume
# 0            Flávio Bolsonaro         10194.0
# 1                   Voldemort         10247.0
# 2                      Coreia         13544.0
# 3                      Cheiro         14234.0
# 4                       Rolex         15334.0
# 5            Senador Jorginho         17134.0
# 6            Carlos Bolsonaro         19900.0
# 7            Bolsa de Valores         21864.0
# 8                   Las Vegas         22197.0
# 9                     Memphis         22368.0
# 10                     Napoli         23404.0
# 11                      Angel        247272.0
# 12                       MTST         24730.0
# 13            Kristen Stewart         24831.0
# 14                      Cadiz         31640.0
# 15             RenanVagabundo         35219.0
# 16                     Koeman         39831.0
# 17           FILMES CARLADIAZ         41630.0
# 18                       Roma         54139.0
# 19            Nintendo Direct         80439.0
# 20              Transcendendo             NaN
# 21          VerdadesSecretas2             NaN
# 22          LA RAFA EST BELLE             NaN
# 23                     Boulos             NaN
# 24              #LaLigaNaESPN             NaN
# 25            #VisibilidadeBi             NaN
# 26                      Girão             NaN
# 27            POLIETTE NO TVZ             NaN
# 28                      Depay             NaN
# 29                    Bovespa             NaN
# 30                       Zico             NaN
# 31               Luuk De Jong             NaN
# 32                     Ferrão             NaN
# 33                       Zyra             NaN
# 34                     Stegen             NaN
# 35                   Leozinho             NaN
# 36              Sergi Roberto             NaN
# 37                  Contarato             NaN
# 38                    invasão             NaN
# 39               Thiago Silva             NaN
# 40                      Japão             NaN
# 41                    Sormani             NaN
# 42                  Jean Mota             NaN
# 43              Danilo Trento             NaN
# 44                     Egídio             NaN
# 45                     Heinze             NaN
# 46                       Joji             NaN
# 47              Samuel Xavier             NaN
# 48   ONE YEAR OF ENOLA HOLMES             NaN
# 49                     Hemmer             NaN

# %%
df["\ttweet_volume"] = pd.to_numeric(df["\ttweet_volume"])
df2 = df.sort_values(by=['\ttweet_volume'], ascending=[False])
df2
# Out:
#                        \tname  \ttweet_volume
# 11                      Angel        247272.0
# 19            Nintendo Direct         80439.0
# 18                       Roma         54139.0
# 17           FILMES CARLADIAZ         41630.0
# 16                     Koeman         39831.0
# 15             RenanVagabundo         35219.0
# 14                      Cadiz         31640.0
# 13            Kristen Stewart         24831.0
# 12                       MTST         24730.0
# 10                     Napoli         23404.0
# 9                     Memphis         22368.0
# 8                   Las Vegas         22197.0
# 7            Bolsa de Valores         21864.0
# 6            Carlos Bolsonaro         19900.0
# 5            Senador Jorginho         17134.0
# 4                       Rolex         15334.0
# 3                      Cheiro         14234.0
# 2                      Coreia         13544.0
# 1                   Voldemort         10247.0
# 0            Flávio Bolsonaro         10194.0
# 20              Transcendendo             NaN
# 21          VerdadesSecretas2             NaN
# 22          LA RAFA EST BELLE             NaN
# 23                     Boulos             NaN
# 24              #LaLigaNaESPN             NaN
# 25            #VisibilidadeBi             NaN
# 26                      Girão             NaN
# 27            POLIETTE NO TVZ             NaN
# 28                      Depay             NaN
# 29                    Bovespa             NaN
# 30                       Zico             NaN
# 31               Luuk De Jong             NaN
# 32                     Ferrão             NaN
# 33                       Zyra             NaN
# 34                     Stegen             NaN
# 35                   Leozinho             NaN
# 36              Sergi Roberto             NaN
# 37                  Contarato             NaN
# 38                    invasão             NaN
# 39               Thiago Silva             NaN
# 40                      Japão             NaN
# 41                    Sormani             NaN
# 42                  Jean Mota             NaN
# 43              Danilo Trento             NaN
# 44                     Egídio             NaN
# 45                     Heinze             NaN
# 46                       Joji             NaN
# 47              Samuel Xavier             NaN
# 48   ONE YEAR OF ENOLA HOLMES             NaN
# 49                     Hemmer             NaN

# %%
graf_linha = sns.lineplot(data = df2, x="\tname", y="\ttweet_volume", color = "red" )
graf_linha.set_title("Twitter Trending Topics")
plt.xticks(rotation=90)
plt.show(graf_linha, figsize=(10, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-ca6e0fe4d33f> in <module>()
#       2 graf_linha.set_title("Twitter Trending Topics")
#       3 plt.xticks(rotation=90)
# ----> 4 plt.show(graf_linha, figsize=(10, 10))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# TypeError: show() got an unexpected keyword argument 'figsize'
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
